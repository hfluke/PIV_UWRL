# %% [markdown]
# * preprocessing
#   * CLAHE
#   * intensity capping
#   * highpass filtering
#   * edge detection
#   * none of these improved the video by much; probably not worth pursuing further
# * adcp
#   * read manual
#   * can download discharge information
#   * not yet sure how to access velocity data, but it seems to be stored somehow; can pursue
# * radar
#   * can get $xy$ coordinates given height and tilt angle (see GeoGebra)
#   * need to map results to gps coordinates or cam-config dst coordinates
# * videos
#   * waterlab videos are still 10 sec (not 40 sec)
#   * don't have access to BSF videos; may need to get code for server (again)
# * work during fall semester ?
# * Planning to meet up with Razin this week (?)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
image = cv2.imread('July/results/video_capture_2024-07-01_09-08-21_velocimetry_results.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 8))
plt.imshow(image)
plt.axis('off')
plt.show()
plt.clf()

image = cv2.imread('CLAHE/results/video_capture_2024-07-01_09-08-21_clahe#clip=7#tile=4.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 8))
plt.imshow(image)
plt.axis('off')
plt.show()
plt.clf()
