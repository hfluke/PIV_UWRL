# %%
import pandas as pd

# %%
df = pd.read_csv(
    filepath_or_buffer="RSS_data_Dec10.csv", 
    # header=[i for i in range(5)],
    header=2,
    skiprows=[3,4]
)
df
# Out:
#            TIMESTAMP  RECORD  BattV_Min   PTemp  Baudrate  \
# 0      9/12/24 13:00       0      12.57  18.050         1
# 1      9/12/24 14:00       1      12.43  20.350         1
# 2      9/12/24 15:00       2      12.42  22.810         1
# 3      9/12/24 16:00       3      12.43  17.210         1
# 4      9/12/24 17:00       4      12.43  19.000         1
# ...              ...     ...        ...     ...       ...
# 2133  12/10/24 10:00    2133      13.07  -8.700         1
# 2134  12/10/24 11:00    2134      12.98  -6.158         1
# 2135  12/10/24 12:00    2135      12.94  -4.818         1
# 2136  12/10/24 13:00    2136      12.88  -2.298         1
# 2137  12/10/24 14:00    2137      12.84  -0.266         1
#
#       Instantanous_velocity  Average_velocity  velocity_unit  \
# 0                       927               943              1
# 1                       956               995              1
# 2                       956               956              1
# ...
