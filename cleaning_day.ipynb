# %%
import pandas as pd

# %%
df = pd.read_csv('AOI_analysis.csv')
df
# Out:
#                                     video  original_AOI_area  \
# 0   video_capture_2024-01-01_07-51-43.mp4             197.47
# 1   video_capture_2024-01-03_08-19-59.mp4             197.47
# 2   video_capture_2024-01-05_08-46-21.mp4             197.47
# 3   video_capture_2024-01-07_08-37-26.mp4             197.47
# 4   video_capture_2024-02-02_07-44-13.mp4             197.47
# 5   video_capture_2024-02-03_17-22-03.mp4             197.47
# 6   video_capture_2024-02-05_15-45-23.mp4             197.47
# 7   video_capture_2024-02-07_14-41-34.mp4             197.47
# 8   video_capture_2024-03-02_11-51-30.mp4             197.47
# 9   video_capture_2024-03-04_07-14-22.mp4             197.47
# 10  video_capture_2024-03-05_15-23-47.mp4             197.47
# 11  video_capture_2024-03-07_11-06-11.mp4             197.47
# 12  video_capture_2024-04-10_18-31-05.mp4             197.47
# 13  video_capture_2024-04-12_10-57-57.mp4             197.47
# ...

# %%
df = pd.read_csv('AOI_bounded.csv')
df
# Out:
#              y      x  dim_0       v_x       v_y      s2n     corr  \
# 0        9.805  0.175     31 -0.014715  0.037154  2.96000  0.47408
# 1        9.805  0.305     31 -0.026260 -0.001301  2.88624  0.47184
# 2        9.805  0.435     31  0.017120 -0.028240  2.94712  0.47656
# 3        9.805  0.565     31 -0.000887  0.058065  2.89232  0.46888
# 4        9.805  0.695     31 -0.005902 -0.002295  2.87496  0.46552
# ...        ...    ...    ...       ...       ...      ...      ...
# 4623103  0.185  2.755  15093  0.000080  0.000000  3.12472  0.70752
# 4623104  0.185  2.885  15093  0.000880 -0.000160  1.83688  0.46960
# 4623105  0.185  3.015  15093  0.028640  0.002320  1.31952  0.23464
# 4623106  0.185  3.145  15093  0.238618 -0.099837  1.35456  0.07712
# 4623107  0.185  3.275  15093  0.542823 -0.046613  2.41240  0.34936
#
#                  xp         yp         xs  ...  turbidity LRO_discharge  \
# 0         361.32126  685.89430   5.118785  ...       2.09       3.50000
# ...
