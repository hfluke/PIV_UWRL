# %%
import pandas as pd

# %%
df1 = pd.read_csv("RSQ/LR_WaterLab_AA_20241213_155924_T01.ENU.vel")
# df2 = pd.read_csv("RSQ/LR_WaterLab_AA_20241213_155924_T02.ENU.vel")
# df3 = pd.read_csv("RSQ/LR_WaterLab_AA_20241213_155924_T03.ENU.vel")
# df4 = pd.read_csv("RSQ/LR_WaterLab_AA_20241213_155924_T04.ENU.vel")
# df5 = pd.read_csv("RSQ/LR_WaterLab_AA_20241213_155924_T05.ENU.vel")
# df6 = pd.read_csv("RSQ/LR_WaterLab_AA_20241213_155924_T06.ENU.vel")
# df7 = pd.read_csv("RSQ/LR_WaterLab_AA_20241213_155924_T07.ENU.vel")
# df8 = pd.read_csv("RSQ/LR_WaterLab_AA_20241213_155924_T08.ENU.vel")
df1
# Out:
#      Station #              Date/Time Frequency (MHz) Profile Type  Depth (m)  \
# 0          335  12/13/2024 3:40:21 PM            3MHz           BB      0.465
# 1          336  12/13/2024 3:40:22 PM            3MHz           BB      0.467
# 2          337  12/13/2024 3:40:23 PM            3MHz           BB      0.468
# 3          338  12/13/2024 3:40:24 PM            3MHz           BB      0.466
# 4          339  12/13/2024 3:40:25 PM            3MHz           BB      0.467
# ..         ...                    ...             ...          ...        ...
# 122        457  12/13/2024 3:42:23 PM            3MHz           PC      0.374
# 123        458  12/13/2024 3:42:24 PM            3MHz           PC      0.378
# 124        459  12/13/2024 3:42:25 PM            3MHz           PC      0.376
# 125        460  12/13/2024 3:42:26 PM            3MHz           PC      0.373
# 126        461  12/13/2024 3:42:27 PM            3MHz           PC      0.379
#
# ...

# %%
df1.columns.values
# Out:
# array(['Station #', 'Date/Time', 'Frequency (MHz)', 'Profile Type',
#        'Depth (m)', 'Cell Size (m)', 'Cell Start (m)',
#        'Cell1 Location (m)', 'Cell1 V1 (m/s)', 'Cell1 V2 (m/s)',
#        'Cell1 V3 (m/s)', 'Cell1 V4 (m/s)', 'Cell1 Spd (m/s)',
#        'Cell1 Dir (deg)', 'Cell1 NVel (m/s)', 'Cell2 Location (m)',
#        'Cell2 V1 (m/s)', 'Cell2 V2 (m/s)', 'Cell2 V3 (m/s)',
#        'Cell2 V4 (m/s)', 'Cell2 Spd (m/s)', 'Cell2 Dir (deg)',
#        'Cell2 NVel (m/s)', 'Cell3 Location (m)', 'Cell3 V1 (m/s)',
#        'Cell3 V2 (m/s)', 'Cell3 V3 (m/s)', 'Cell3 V4 (m/s)',
#        'Cell3 Spd (m/s)', 'Cell3 Dir (deg)', 'Cell3 NVel (m/s)',
#        'Cell4 Location (m)', 'Cell4 V1 (m/s)', 'Cell4 V2 (m/s)',
#        'Cell4 V3 (m/s)', 'Cell4 V4 (m/s)', 'Cell4 Spd (m/s)',
#        'Cell4 Dir (deg)', 'Cell4 NVel (m/s)', 'Cell5 Location (m)',
#        'Cell5 V1 (m/s)', 'Cell5 V2 (m/s)', 'Cell5 V3 (m/s)',
#        'Cell5 V4 (m/s)', 'Cell5 Spd (m/s)', 'Cell5 Dir (deg)',
# ...

# %%
df1[[
    'Station #', 'Date/Time', 'Frequency (MHz)', 'Profile Type',
    'Depth (m)', 'Cell Size (m)', 'Cell Start (m)',
    'Cell1 Location (m)', 'Cell1 V1 (m/s)', 'Cell1 V2 (m/s)',
    'Cell1 V3 (m/s)', 'Cell1 V4 (m/s)', 'Cell1 Spd (m/s)',
    'Cell1 Dir (deg)', 'Cell1 NVel (m/s)'
]]
# Out:
#      Station #              Date/Time Frequency (MHz) Profile Type  Depth (m)  \
# 0          335  12/13/2024 3:40:21 PM            3MHz           BB      0.465
# 1          336  12/13/2024 3:40:22 PM            3MHz           BB      0.467
# 2          337  12/13/2024 3:40:23 PM            3MHz           BB      0.468
# 3          338  12/13/2024 3:40:24 PM            3MHz           BB      0.466
# 4          339  12/13/2024 3:40:25 PM            3MHz           BB      0.467
# ..         ...                    ...             ...          ...        ...
# 122        457  12/13/2024 3:42:23 PM            3MHz           PC      0.374
# 123        458  12/13/2024 3:42:24 PM            3MHz           PC      0.378
# 124        459  12/13/2024 3:42:25 PM            3MHz           PC      0.376
# 125        460  12/13/2024 3:42:26 PM            3MHz           PC      0.373
# 126        461  12/13/2024 3:42:27 PM            3MHz           PC      0.379
#
# ...

# %%
df1.sort_values(by='Depth (m)')
# Out:
#     Station #              Date/Time Frequency (MHz) Profile Type  Depth (m)  \
# 94        429  12/13/2024 3:41:55 PM            3MHz           PC      0.311
# 93        428  12/13/2024 3:41:54 PM            3MHz           PC      0.330
# 92        427  12/13/2024 3:41:53 PM            3MHz           BB      0.336
# 95        430  12/13/2024 3:41:56 PM            3MHz           PC      0.341
# 96        431  12/13/2024 3:41:57 PM            3MHz           PC      0.350
# ..        ...                    ...             ...          ...        ...
# 54        389  12/13/2024 3:41:15 PM            3MHz           BB      0.705
# 57        392  12/13/2024 3:41:18 PM            3MHz           BB      0.706
# 63        398  12/13/2024 3:41:24 PM            3MHz         PCBB      0.709
# 61        396  12/13/2024 3:41:22 PM            3MHz           BB      0.711
# 52        387  12/13/2024 3:41:13 PM            3MHz           BB      0.726
#
# ...
